# %% [markdown]
# # Problem Setup
#
# This notebook records the agreed task definition for the FYP implementation: MNIST `3 vs 8`, normalized inputs in `[0,1]`, and a joint dictionary learning + SVM objective solved by proximal gradient with backtracking.

# %%
from src.config import default_data_config, default_hyperparams
from src.data import load_mnist_3vs8

data_cfg = default_data_config()
hyper = default_hyperparams()

X_train, y_train, X_val, y_val, X_test, y_test = load_mnist_3vs8(
    positive_digit=data_cfg.positive_digit,
    negative_digit=data_cfg.negative_digit,
    train_size=data_cfg.train_size,
    val_size=data_cfg.val_size,
    test_size=data_cfg.test_size,
    normalize=data_cfg.normalize,
    random_state=data_cfg.random_state,
)

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
